# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler,MinMaxScaler,OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
validation_df = pd.read_csv("Validation.csv")
validation_df.tail()
# Out:
#             car_name    brand   model  vehicle_age  km_driven seller_type
# 15405  Hyundai Grand  Hyundai   Grand            5       9229      Dealer  \
# 15406    Hyundai i10  Hyundai     i10            9      10723      Dealer
# 15407  Maruti Ertiga   Maruti  Ertiga            2      18000      Dealer
# 15408    Skoda Rapid    Skoda   Rapid            6      67000      Dealer
# 15409     Honda City    Honda    City            2      13000      Dealer
#
#       fuel_type transmission_type  mileage  engine  max_power  seats
# 15405    Petrol            Manual    18.90    1197      82.00      5  \
# 15406    Petrol            Manual    19.81    1086      68.05      5
# 15407    Petrol            Manual    17.50    1373      91.10      7
# 15408    Diesel            Manual    21.14    1498     103.52      5
# 15409    Petrol         Automatic    18.00    1497     117.60      5
#
#        selling_price
# 15405         545000
# 15406         250000
# 15407         925000
# 15408         425000
# 15409        1200000

# %%
#Encoding Categorical Var
